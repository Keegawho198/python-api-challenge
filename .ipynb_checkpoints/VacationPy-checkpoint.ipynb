# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
from pathlib import Path

# Import API key
from api_keys import geoapify_key

#print(geoapify_key)

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
csv_file = Path("output_data/cities.csv")
city_data_df = pd.read_csv(csv_file)

# Display sample data
city_data_df.head()
# Out:
#    City_ID                   City      Lat       Lng  Max Temp  Humidity  \
# 0        0                 kodiak  57.7900 -152.4072      7.73        71
# 1        1                 saipan  15.1355  145.7010     28.39        83
# 2        2      wailua homesteads  22.0669 -159.3780     28.44        70
# 3        3  astaneh-ye ashrafiyeh  37.2596   49.9444     18.09        93
# 4        4              adamstown -25.0660 -130.1015     21.56        89
#
#    Cloudiness  Wind Speed Country        Date
# 0         100        4.12      US  1727404077
# 1          75        5.14      MP  1727404079
# 2          20        5.14      US  1727404080
# 3          72        2.24      IR  1727404082
# 4          85        4.37      PN  1727404083

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
# YOUR CODE HERE

map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM"
)

# Display the map

map_plot_1

#refer to day 3 - Act 6
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
#TESTING
print(city_data_df.head())
#print(city_data_df['Max Temp'].unique())
#print(city_data_df['Wind Speed'].unique())
#print(city_data_df['Cloudiness'].unique())




# Narrow down cities that fit criteria
# For example, let's say we want to filter cities with a temperature greater than 20 degrees
#filtered_city_data_df = city_data_df[city_data_df['Max Temp'] > 20]  

#filters for 
#A max temperature lower than 27 degrees but higher than 21
#Wind speed less than 4.5 m/s
#Zero cloudiness

#filtered_city_data_df = city_data_df[
 #   (city_data_df['Max Temp'] < 27) & 
 #   (city_data_df['Max Temp'] > 21) & 
 #   (city_data_df['Wind Speed'] < 4.5) & 
 #   (city_data_df['Cloudiness'] == 0)
#]

#print(filtered_city_data_df)

# Drop any rows with null values
#filtered_city_data_df = filtered_city_data_df.dropna()

# Display sample data
#filtered_city_data_df.head()

#check for NA values - testing
#has_na = filtered_city_data_df.isna().any().any()
#print("Does the DataFrame have any NA values?", has_na)
#na_columns = filtered_city_data_df.isna().sum()
#print("Number of NA values in each column:\n", na_columns)
# Out:
#    City_ID                   City      Lat       Lng  Max Temp  Humidity  \
# 0        0                 kodiak  57.7900 -152.4072      7.73        71
# 1        1                 saipan  15.1355  145.7010     28.39        83
# 2        2      wailua homesteads  22.0669 -159.3780     28.44        70
# 3        3  astaneh-ye ashrafiyeh  37.2596   49.9444     18.09        93
# 4        4              adamstown -25.0660 -130.1015     21.56        89
#
#    Cloudiness  Wind Speed Country        Date
# 0         100        4.12      US  1727404077
# 1          75        5.14      MP  1727404079
# 2          20        5.14      US  1727404080
# 3          72        2.24      IR  1727404082
# 4          85        4.37      PN  1727404083

# %%
# Narrow down cities that fit criteria and drop any results with null values
#filters for 
#A max temperature lower than 27 degrees but higher than 20
#Wind speed less than 4.5 m/s
#Zero cloudiness
filtered_city_df = city_data_df[
    (city_data_df['Max Temp'] < 27) & 
    (city_data_df['Max Temp'] > 20) & 
    (city_data_df['Wind Speed'] < 4.5) & 
    (city_data_df['Cloudiness'] == 0)
]

# Drop any rows with null values
filtered_city_df = filtered_city_df.dropna()

# Display sample data
filtered_city_df
# Out:
#      City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 16        16        newman  37.3138 -121.0208     25.58        53           0
# 97        97     brookings  44.3114  -96.7984     20.10        57           0
# 206      206       termoli  41.9888   14.9895     21.69        66           0
# 218      218         hotan  37.0997   79.9269     25.48        19           0
# 246      246  mersa matruh  31.3525   27.2453     24.11        60           0
# 277      277      zhuanghe  39.7008  122.9911     22.09        43           0
# 337      337     box elder  41.5005 -112.8764     21.82        38           0
# 360      360    dayr hafir  36.1569   37.7078     23.16        41           0
# 390      390         tabas  33.5959   56.9244     23.96        32           0
# 422      422       tripoli  32.8752   13.1875     26.78        52           0
# 440      440          argo  37.6333   22.7333     21.85        59           0
# 454      454      faliraki  36.3398   28.1994     23.98        73           0
# 468      468    siwa oasis  29.2041   25.5195     24.28        57           0
# 474      474      galliano  29.4422  -90.2992     23.00        64           0
# 527      527     tazacorte  28.6290  -17.9293     22.54        90           0
#
#      Wind Speed Country        Date
# 16         0.45      US  1727404099
# 97         4.12      US  1727404216
# 206        4.15      IT  1727404366
# 218        4.10      CN  1727404384
# 246        2.57      EG  1727404419
# 277        1.77      CN  1727404460
# 337        1.91      US  1727404545
# 360        3.41      SY  1727404581
# 390        4.01      IR  1727404623
# 422        2.86      LY  1727404670
# 440        1.55      GR  1727404699
# 454        3.60      GR  1727404719
# 468        2.54      EG  1727404741
# 474        3.60      US  1727404750
# 527        4.12      ES  1727404827

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
# YOUR CODE HERE
hotel_df = filtered_city_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
# YOUR CODE HERE
hotel_df['Hotel Name'] = ''


# Display sample data
# YOUR CODE HERE
hotel_df
# Out:
#              City Country      Lat       Lng  Humidity Hotel Name
# 16         newman      US  37.3138 -121.0208        53
# 97      brookings      US  44.3114  -96.7984        57
# 206       termoli      IT  41.9888   14.9895        66
# 218         hotan      CN  37.0997   79.9269        19
# 246  mersa matruh      EG  31.3525   27.2453        60
# 277      zhuanghe      CN  39.7008  122.9911        43
# 337     box elder      US  41.5005 -112.8764        38
# 360    dayr hafir      SY  36.1569   37.7078        41
# 390         tabas      IR  33.5959   56.9244        32
# 422       tripoli      LY  32.8752   13.1875        52
# 440          argo      GR  37.6333   22.7333        59
# 454      faliraki      GR  36.3398   28.1994        73
# 468    siwa oasis      EG  29.2041   25.5195        57
# 474      galliano      US  29.4422  -90.2992        64
# 527     tazacorte      ES  28.6290  -17.9293        90

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = # YOUR CODE HERE
params = {
    # YOUR CODE HERE
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = row["Lat"]
    longitude = row["Lng"]

    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = # YOUR CODE HERE
    params["bias"] = # YOUR CODE HERE

    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionary
    name_address = # YOUR CODE HERE

    # Convert the API response to JSON format
    name_address = # YOUR CODE HERE

    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"

    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# bijelo polje - nearest hotel: Hotel Franca
# shiprock - nearest hotel: No hotel found
# port elizabeth - nearest hotel: Waterford Hotel
# hamilton - nearest hotel: North Vista Manor
# waycross - nearest hotel: Holiday Inn Express & Suites
# jamestown - nearest hotel: DoubleTree Jamestown
# bonne terre - nearest hotel: Bonneville Motel
# laguna - nearest hotel: Holiday Inn Express & Suites
# cristuru secuiesc - nearest hotel: Kúria Vendégház
# badger - nearest hotel: Clarion Hotel & Suites
# morehead city - nearest hotel: Bask Hotel Big Rock Landing, Trademark Collection by Wyndham
# koryazhma - nearest hotel: Виконда
# sparti - nearest hotel: Maniatis
# revda - nearest hotel: Металлург
# mermoz boabab - nearest hotel: La maison blanche
# mount pleasant - nearest hotel: Old Village Post House
# nova vicosa - nearest hotel: Pousada Pontal da Barra
# rio de janeiro - nearest hotel: Ibis Rio porto atlantico
# qorveh - nearest hotel: No hotel found
# vaison-la-romaine - nearest hotel: Hostellerie le Beffroi
# newman - nearest hotel: No hotel found
# demopolis - nearest hotel: No hotel found
# port douglas - nearest hotel: Mantra Aqueous Port Douglas
# sarkisla - nearest hotel: No hotel found
# fort bragg - nearest hotel: Airborne Inn Lodging
#                   City Country      Lat       Lng  Humidity  \
# 13        bijelo polje      ME  43.0337   19.7470        51
# 39            shiprock      US  36.7855 -108.6870        14
# 58      port elizabeth      ZA -33.9180   25.5701        60
# 82            hamilton      US  39.1834  -84.5333        82
# 109           waycross      US  31.2136  -82.3540        94
# 125          jamestown      US  42.0970  -79.2353        88
# 193        bonne terre      US  37.9231  -90.5554        89
# 202             laguna      US  38.4210 -121.4238        53
# 215  cristuru secuiesc      RO  46.2833   25.0333        60
# 219             badger      US  64.8000 -147.5333        42
# 233      morehead city      US  34.7229  -76.7260        77
# 237          koryazhma      RU  61.3143   47.1691        39
# 239             sparti      GR  37.0733   22.4297        21
# 249              revda      RU  56.8010   59.9303        43
# 298      mermoz boabab      SN  14.7065  -17.4758        83
# 304     mount pleasant      US  32.7941  -79.8626        86
# 311        nova vicosa      BR -17.8919  -39.3719        88
# 358     rio de janeiro      BR -22.9028  -43.2075        78
# 374             qorveh      IR  35.1664   47.8045        21
# 378  vaison-la-romaine      FR  44.2390    5.0750        60
# 459             newman      US  37.3138 -121.0208        55
# 474          demopolis      US  32.5176  -87.8364       100
# 482       port douglas      AU -16.4833  145.4667        62
# 491           sarkisla      TR  39.3519   36.4098        32
# 497         fort bragg      US  35.1390  -79.0060        79
#
#                                             Hotel Name
# 13                                        Hotel Franca
# 39                                      No hotel found
# 58                                     Waterford Hotel
# 82                                   North Vista Manor
# 109                       Holiday Inn Express & Suites
# 125                               DoubleTree Jamestown
# 193                                   Bonneville Motel
# 202                       Holiday Inn Express & Suites
# 215                                    Kúria Vendégház
# 219                             Clarion Hotel & Suites
# 233  Bask Hotel Big Rock Landing, Trademark Collect...
# 237                                            Виконда
# 239                                           Maniatis
# 249                                          Металлург
# 298                                  La maison blanche
# 304                             Old Village Post House
# 311                            Pousada Pontal da Barra
# 358                           Ibis Rio porto atlantico
# 374                                     No hotel found
# 378                             Hostellerie le Beffroi
# 459                                     No hotel found
# 474                                     No hotel found
# 482                        Mantra Aqueous Port Douglas
# 491                                     No hotel found
# 497                               Airborne Inn Lodging

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
# YOUR CODE HERE

# Display the map
# YOUR CODE HERE
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
